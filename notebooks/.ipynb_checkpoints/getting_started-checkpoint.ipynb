# %% [markdown]
# # 🤖 Copilot-IA - Getting Started
#
# Este notebook demonstra como usar os copilotos de desenvolvimento do Copilot-IA.
#
# ## Pré-requisitos
#
# 1. Instalar dependências: `pip install -r requirements.txt`
# 2. Configurar variável de ambiente: `OPENAI_API_KEY`

# %%
# Setup inicial
import os
import sys

# Adicionar raiz do projeto ao path
sys.path.insert(0, '..')

# Configurar logging
from src.utils import setup_logging
setup_logging(level="INFO")

# %% [markdown]
# ## 1. Code Reviewer
#
# O Code Reviewer analisa código e identifica problemas.

# %%
from src.copilots import CodeReviewerCopilot

# Código de exemplo com problemas
sample_code = '''
def get_user(id):
    query = f"SELECT * FROM users WHERE id = {id}"
    result = db.execute(query)
    return result

def process_data(data):
    for i in range(len(data)):
        data[i] = data[i] * 2
    return data
'''

# Inicializar e executar
reviewer = CodeReviewerCopilot()
result = reviewer.analyze_code(sample_code, language="python")

print(result.content)
# Out:
# # Revisão de Código
#
# ## Resumo Executivo
#
# O código fornecido consiste em duas funções: `get_user`, que executa uma consulta SQL para recuperar um usuário pelo ID, e `process_data`, que processa uma lista de dados multiplicando cada elemento por dois. A análise identificou problemas significativos de segurança e performance, além de oportunidades para melhorar a legibilidade e manutenibilidade.
#
# ## Problemas Encontrados
#
# 1. **Injeção de SQL (Alta Severidade)**
#    - A função `get_user` constrói a consulta SQL concatenando diretamente o ID do usuário, o que pode levar a vulnerabilidades de injeção de SQL.
#
# 2. **Validação de Entrada Insuficiente (Média Severidade)**
#    - Não há validação para garantir que o `id` passado para `get_user` seja um número válido.
#
# 3. **Ineficiência no Loop (Baixa Severidade)**
#    - A função `process_data` utiliza `range(len(data))` para iterar sobre a lista, o que é menos eficiente e menos legível do que iterar diretamente sobre os elementos da lista.
#
# 4. **Legibilidade e Manutenibilidade (Baixa Severidade)**
#    - Falta de documentação e comentários explicativos sobre o propósito e funcionamento das funções.
#
# 5. **Uso de f-strings para SQL (Média Severidade)**
#    - Embora f-strings sejam uma prática comum para formatação de strings, seu uso em consultas SQL é desencorajado devido ao risco de injeção de SQL.
#
# ## Sugestões de Correção
#
# 1. **Prevenir Injeção de SQL**
#    - Utilize consultas parametrizadas para evitar injeção de SQL. Por exemplo:
#      ```python
#      def get_user(id):
#          query = "SELECT * FROM users WHERE id = ?"
#          result = db.execute(query, (id,))
#          return result
#      ```
#
# 2. **Validação de Entrada**
#    - Adicione validação para garantir que `id` seja um número inteiro válido:
#      ```python
#      def get_user(id):
#          if not isinstance(id, int):
#              raise ValueError("ID must be an integer")
#          query = "SELECT * FROM users WHERE id = ?"
#          result = db.execute(query, (id,))
#          return result
#      ```
#
# 3. **Melhorar a Eficiência do Loop**
#    - Itere diretamente sobre os elementos da lista:
#      ```python
#      def process_data(data):
#          return [x * 2 for x in data]
#      ```
#
# 4. **Adicionar Documentação**
#    - Inclua docstrings para descrever o propósito e o funcionamento de cada função:
#      ```python
#      def get_user(id):
#          """
#          Retrieve a user from the database by ID.
#
#          Parameters:
#          id (int): The ID of the user to retrieve.
#
#          Returns:
#          result: The database query result.
#          """
#          # Function implementation...
#      ```
#
# ## Score de Qualidade
#
# **4/10**
#
# - A presença de uma vulnerabilidade de segurança crítica e a falta de validação de entrada são os principais fatores que reduzem o score de qualidade.
#
# ## Recomendações Gerais
#
# - Sempre utilize consultas parametrizadas ao trabalhar com SQL para evitar injeções.
# - Valide todas as entradas de usuário para garantir que atendam aos requisitos esperados.
# - Prefira métodos de iteração mais eficientes e legíveis, como list comprehensions.
# - Documente o código adequadamente para facilitar a manutenção e a compreensão futura.
# - Considere adicionar testes unitários para garantir que as funções se comportem conforme o esperado em diferentes cenários.
